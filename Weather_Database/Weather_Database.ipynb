# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Generate random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# When this cell is executed, the output is a zip object in memory
# The zip object packs each pair of lats and longs having the same index in their respective array
# into a tuple

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=cfccf99a57064a2ba06c02ec6bb12e9d

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning of data retrieval          ")
print("-------------------------------------")

# Create the counters and initialize to 1 because the first iteration of logging for each recorded response and
# the set needs to start at 1
record_count = 1
set_count = 1


# Every time a city is referenced in the code, the index on the cities list needs to be used
# This will cause programming errors when building city_url because it adds to the index, not the city name to
# city_url
# To fix this issue, another for loop needs to be created in order to the city from the cities list
# Instead of using two for loops, use the enumerate() method as an alternative way to iterate through the list 
# of cities and retrieve both the index and city from the list

# Loop through the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Add a try-except block to prevent API requests from stopping prematurelyy if the city_weather requests is 
# not a valuid request
# If the request isn't valid, the code ill not find the first item requested, which is the dictionary "coord"
# The code will skip the city and continue to run

# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description": city_description})
        
# If an error is given, skip the city
    except:
        print("City not found.  Skipping...")
        pass
    
# Indicate the date loading is complete
print("------------------------------")
print("Date retrieval complete       ")
print("------------------------------")
# Out:
# Beginning of data retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | khatanga
# Processing Record 2 of Set 1 | jablanica
# Processing Record 3 of Set 1 | iquitos
# Processing Record 4 of Set 1 | atuona
# Processing Record 5 of Set 1 | kunda
# Processing Record 6 of Set 1 | tutoia
# Processing Record 7 of Set 1 | vao
# Processing Record 8 of Set 1 | barrow
# Processing Record 9 of Set 1 | usinsk
# Processing Record 10 of Set 1 | punta arenas
# Processing Record 11 of Set 1 | ca mau
# Processing Record 12 of Set 1 | norman wells
# Processing Record 13 of Set 1 | lorengau
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | tsihombe
# City not found.  Skipping...
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | novoorsk
# Processing Record 19 of Set 1 | belushya guba
# City not found.  Skipping...
# Processing Record 20 of Set 1 | lavrentiya
# Processing Record 21 of Set 1 | urengoy
# Processing Record 22 of Set 1 | gucheng
# Processing Record 23 of Set 1 | phan thiet
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | alice springs
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | ukiah
# Processing Record 30 of Set 1 | jijiga
# Processing Record 31 of Set 1 | ormara
# Processing Record 32 of Set 1 | rognan
# Processing Record 33 of Set 1 | bluff
# Processing Record 34 of Set 1 | ugoofaaru
# Processing Record 35 of Set 1 | cape town
# Processing Record 36 of Set 1 | richards bay
# Processing Record 37 of Set 1 | sitka
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | alugan
# Processing Record 40 of Set 1 | busselton
# Processing Record 41 of Set 1 | hobart
# Processing Record 42 of Set 1 | padang
# Processing Record 43 of Set 1 | russell
# Processing Record 44 of Set 1 | poum
# Processing Record 45 of Set 1 | sao joao da barra
# Processing Record 46 of Set 1 | banda aceh
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | touros
# Processing Record 50 of Set 1 | grand-santi
# Processing Record 1 of Set 2 | front royal
# Processing Record 2 of Set 2 | ayagoz
# Processing Record 3 of Set 2 | gondanglegi
# Processing Record 4 of Set 2 | puerto ayora
# Processing Record 5 of Set 2 | san ramon
# Processing Record 6 of Set 2 | dargaville
# Processing Record 7 of Set 2 | taolanaro
# City not found.  Skipping...
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | longyearbyen
# Processing Record 10 of Set 2 | muros
# Processing Record 11 of Set 2 | okhotsk
# Processing Record 12 of Set 2 | hobyo
# Processing Record 13 of Set 2 | kerema
# Processing Record 14 of Set 2 | buluang
# Processing Record 15 of Set 2 | chester
# Processing Record 16 of Set 2 | katsuura
# Processing Record 17 of Set 2 | kodiak
# Processing Record 18 of Set 2 | jatiroto
# Processing Record 19 of Set 2 | namibe
# Processing Record 20 of Set 2 | ola
# Processing Record 21 of Set 2 | torbay
# Processing Record 22 of Set 2 | mentok
# City not found.  Skipping...
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | ostrovnoy
# Processing Record 25 of Set 2 | halifax
# Processing Record 26 of Set 2 | tamala
# Processing Record 27 of Set 2 | alamos
# Processing Record 28 of Set 2 | novoulyanovsk
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | mar del plata
# Processing Record 32 of Set 2 | saint george
# Processing Record 33 of Set 2 | kedougou
# Processing Record 34 of Set 2 | khani
# Processing Record 35 of Set 2 | tuktoyaktuk
# Processing Record 36 of Set 2 | homer
# Processing Record 37 of Set 2 | san pedro de macoris
# Processing Record 38 of Set 2 | manokwari
# Processing Record 39 of Set 2 | jamestown
# Processing Record 40 of Set 2 | marang
# Processing Record 41 of Set 2 | comodoro rivadavia
# Processing Record 42 of Set 2 | lebu
# Processing Record 43 of Set 2 | sao filipe
# Processing Record 44 of Set 2 | cardston
# Processing Record 45 of Set 2 | samusu
# City not found.  Skipping...
# Processing Record 46 of Set 2 | urdzhar
# City not found.  Skipping...
# Processing Record 47 of Set 2 | sao sepe
# Processing Record 48 of Set 2 | korla
# Processing Record 49 of Set 2 | tlapa
# City not found.  Skipping...
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | northam
# Processing Record 2 of Set 3 | east london
# Processing Record 3 of Set 3 | marcona
# City not found.  Skipping...
# Processing Record 4 of Set 3 | camacha
# Processing Record 5 of Set 3 | puerto penasco
# Processing Record 6 of Set 3 | hasaki
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | koceljeva
# Processing Record 9 of Set 3 | mandalgovi
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | morehead
# Processing Record 12 of Set 3 | maraa
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | tibagi
# Processing Record 16 of Set 3 | vallenar
# Processing Record 17 of Set 3 | dawei
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | jos
# Processing Record 20 of Set 3 | flinders
# Processing Record 21 of Set 3 | ulagan
# Processing Record 22 of Set 3 | sergeyevka
# Processing Record 23 of Set 3 | port lincoln
# Processing Record 24 of Set 3 | bardiyah
# Processing Record 25 of Set 3 | vanimo
# Processing Record 26 of Set 3 | marawi
# Processing Record 27 of Set 3 | codrington
# Processing Record 28 of Set 3 | kavaratti
# Processing Record 29 of Set 3 | falkoping
# City not found.  Skipping...
# Processing Record 30 of Set 3 | leningradskiy
# Processing Record 31 of Set 3 | natal
# Processing Record 32 of Set 3 | barentsburg
# City not found.  Skipping...
# Processing Record 33 of Set 3 | yamandu
# Processing Record 34 of Set 3 | qaanaaq
# Processing Record 35 of Set 3 | victoria
# Processing Record 36 of Set 3 | los llanos de aridane
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | avarua
# Processing Record 39 of Set 3 | chegdomyn
# Processing Record 40 of Set 3 | honningsvag
# Processing Record 41 of Set 3 | la macarena
# Processing Record 42 of Set 3 | maswa
# Processing Record 43 of Set 3 | attawapiskat
# City not found.  Skipping...
# Processing Record 44 of Set 3 | havelock
# Processing Record 45 of Set 3 | moron
# Processing Record 46 of Set 3 | vila velha
# Processing Record 47 of Set 3 | mys shmidta
# City not found.  Skipping...
# Processing Record 48 of Set 3 | san patricio
# Processing Record 49 of Set 3 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 50 of Set 3 | bengkulu
# Processing Record 1 of Set 4 | asau
# Processing Record 2 of Set 4 | kalmunai
# Processing Record 3 of Set 4 | arinos
# Processing Record 4 of Set 4 | upernavik
# Processing Record 5 of Set 4 | lake charles
# Processing Record 6 of Set 4 | batagay-alyta
# Processing Record 7 of Set 4 | walvis bay
# Processing Record 8 of Set 4 | virginia beach
# Processing Record 9 of Set 4 | jacareacanga
# Processing Record 10 of Set 4 | muisne
# Processing Record 11 of Set 4 | dunedin
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | manono
# Processing Record 14 of Set 4 | grand river south east
# City not found.  Skipping...
# Processing Record 15 of Set 4 | hithadhoo
# Processing Record 16 of Set 4 | cabo san lucas
# Processing Record 17 of Set 4 | jiancheng
# Processing Record 18 of Set 4 | ancud
# Processing Record 19 of Set 4 | maniitsoq
# Processing Record 20 of Set 4 | tautira
# Processing Record 21 of Set 4 | natchitoches
# Processing Record 22 of Set 4 | ambodifototra
# City not found.  Skipping...
# Processing Record 23 of Set 4 | saskylakh
# Processing Record 24 of Set 4 | derzhavinsk
# Processing Record 25 of Set 4 | ciudad bolivar
# Processing Record 26 of Set 4 | nelson bay
# Processing Record 27 of Set 4 | bonavista
# Processing Record 28 of Set 4 | lumsden
# Processing Record 29 of Set 4 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 30 of Set 4 | kloulklubed
# Processing Record 31 of Set 4 | tselinnoye
# Processing Record 32 of Set 4 | new norfolk
# Processing Record 33 of Set 4 | boyolangu
# Processing Record 34 of Set 4 | hilo
# Processing Record 35 of Set 4 | la baule-escoublac
# Processing Record 36 of Set 4 | bambous virieux
# Processing Record 37 of Set 4 | hambantota
# Processing Record 38 of Set 4 | vinh
# Processing Record 39 of Set 4 | svetlaya
# Processing Record 40 of Set 4 | grande prairie
# Processing Record 41 of Set 4 | arraial do cabo
# Processing Record 42 of Set 4 | manaure
# Processing Record 43 of Set 4 | porto velho
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | yanchukan
# City not found.  Skipping...
# Processing Record 46 of Set 4 | amderma
# City not found.  Skipping...
# Processing Record 47 of Set 4 | deputatskiy
# Processing Record 48 of Set 4 | vaitupu
# City not found.  Skipping...
# Processing Record 49 of Set 4 | thaba nchu
# Processing Record 50 of Set 4 | andenes
# Processing Record 1 of Set 5 | karratha
# Processing Record 2 of Set 5 | toulepleu
# City not found.  Skipping...
# Processing Record 3 of Set 5 | lata
# Processing Record 4 of Set 5 | nuuk
# Processing Record 5 of Set 5 | inderborskiy
# City not found.  Skipping...
# Processing Record 6 of Set 5 | perth
# Processing Record 7 of Set 5 | san cristobal
# Processing Record 8 of Set 5 | ulaangom
# Processing Record 9 of Set 5 | shahpur
# Processing Record 10 of Set 5 | viesca
# Processing Record 11 of Set 5 | balboa
# Processing Record 12 of Set 5 | coihaique
# Processing Record 13 of Set 5 | itacarambi
# Processing Record 14 of Set 5 | manzil salim
# Processing Record 15 of Set 5 | sur
# Processing Record 16 of Set 5 | esperance
# Processing Record 17 of Set 5 | kenai
# Processing Record 18 of Set 5 | utete
# Processing Record 19 of Set 5 | bargal
# City not found.  Skipping...
# Processing Record 20 of Set 5 | alta floresta
# Processing Record 21 of Set 5 | lompoc
# Processing Record 22 of Set 5 | oranjemund
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | saldanha
# Processing Record 25 of Set 5 | pio ix
# Processing Record 26 of Set 5 | burica
# City not found.  Skipping...
# Processing Record 27 of Set 5 | mongagua
# Processing Record 28 of Set 5 | pulivendla
# Processing Record 29 of Set 5 | asfi
# Processing Record 30 of Set 5 | codajas
# Processing Record 31 of Set 5 | caravelas
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | kavieng
# Processing Record 34 of Set 5 | paita
# Processing Record 35 of Set 5 | muncar
# Processing Record 36 of Set 5 | palabuhanratu
# City not found.  Skipping...
# Processing Record 37 of Set 5 | meyungs
# City not found.  Skipping...
# Processing Record 38 of Set 5 | gudur
# Processing Record 39 of Set 5 | dalaba
# Processing Record 40 of Set 5 | rudnichnyy
# Processing Record 41 of Set 5 | tucuma
# Processing Record 42 of Set 5 | nikolskoye
# Processing Record 43 of Set 5 | taitung
# Processing Record 44 of Set 5 | castro
# Processing Record 45 of Set 5 | muli
# Processing Record 46 of Set 5 | narsaq
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | bethel
# Processing Record 49 of Set 5 | aswan
# Processing Record 50 of Set 5 | ilulissat
# Processing Record 1 of Set 6 | bubaque
# Processing Record 2 of Set 6 | manzil tamim
# City not found.  Skipping...
# Processing Record 3 of Set 6 | presidente olegario
# Processing Record 4 of Set 6 | nha trang
# Processing Record 5 of Set 6 | mananjary
# Processing Record 6 of Set 6 | guerrero negro
# Processing Record 7 of Set 6 | mattru
# Processing Record 8 of Set 6 | poronaysk
# Processing Record 9 of Set 6 | flin flon
# Processing Record 10 of Set 6 | stornoway
# Processing Record 11 of Set 6 | portland
# Processing Record 12 of Set 6 | sakaiminato
# Processing Record 13 of Set 6 | robertsport
# Processing Record 14 of Set 6 | carnarvon
# Processing Record 15 of Set 6 | akdepe
# Processing Record 16 of Set 6 | ruteng
# Processing Record 17 of Set 6 | mount isa
# Processing Record 18 of Set 6 | wenatchee
# Processing Record 19 of Set 6 | faanui
# Processing Record 20 of Set 6 | malakal
# Processing Record 21 of Set 6 | airai
# Processing Record 22 of Set 6 | chokurdakh
# Processing Record 23 of Set 6 | la ronge
# Processing Record 24 of Set 6 | inuvik
# Processing Record 25 of Set 6 | kousseri
# Processing Record 26 of Set 6 | kontagora
# Processing Record 27 of Set 6 | pangnirtung
# Processing Record 28 of Set 6 | ponta do sol
# Processing Record 29 of Set 6 | khandyga
# Processing Record 30 of Set 6 | saint-philippe
# Processing Record 31 of Set 6 | bilibino
# Processing Record 32 of Set 6 | sahrak
# City not found.  Skipping...
# Processing Record 33 of Set 6 | abu samrah
# Processing Record 34 of Set 6 | provideniya
# Processing Record 35 of Set 6 | mastic
# Processing Record 36 of Set 6 | barra dos coqueiros
# Processing Record 37 of Set 6 | ambulu
# Processing Record 38 of Set 6 | iqaluit
# Processing Record 39 of Set 6 | kahului
# Processing Record 40 of Set 6 | virarajendrapet
# Processing Record 41 of Set 6 | olinda
# Processing Record 42 of Set 6 | nianzishan
# Processing Record 43 of Set 6 | santarem
# Processing Record 44 of Set 6 | pandan
# Processing Record 45 of Set 6 | balykshi
# Processing Record 46 of Set 6 | santa maria del oro
# Processing Record 47 of Set 6 | hovd
# Processing Record 48 of Set 6 | srednekolymsk
# Processing Record 49 of Set 6 | takoradi
# Processing Record 50 of Set 6 | georgetown
# Processing Record 1 of Set 7 | meadow lake
# Processing Record 2 of Set 7 | chifeng
# Processing Record 3 of Set 7 | jiehu
# Processing Record 4 of Set 7 | phayakkhaphum phisai
# Processing Record 5 of Set 7 | cockburn town
# Processing Record 6 of Set 7 | tveit
# Processing Record 7 of Set 7 | port hawkesbury
# Processing Record 8 of Set 7 | vardo
# Processing Record 9 of Set 7 | angoche
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | boa vista
# Processing Record 12 of Set 7 | cherskiy
# Processing Record 13 of Set 7 | barentu
# Processing Record 14 of Set 7 | oktyabrskoye
# Processing Record 15 of Set 7 | harpalpur
# Processing Record 16 of Set 7 | ipixuna
# Processing Record 17 of Set 7 | ivanava
# Processing Record 18 of Set 7 | przhevalskoye
# Processing Record 19 of Set 7 | upata
# Processing Record 20 of Set 7 | skalistyy
# City not found.  Skipping...
# Processing Record 21 of Set 7 | saint-francois
# Processing Record 22 of Set 7 | dingle
# Processing Record 23 of Set 7 | thinadhoo
# Processing Record 24 of Set 7 | havre-saint-pierre
# Processing Record 25 of Set 7 | weyburn
# Processing Record 26 of Set 7 | murray bridge
# Processing Record 27 of Set 7 | veracruz
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | ballina
# Processing Record 30 of Set 7 | grindavik
# Processing Record 31 of Set 7 | geraldton
# Processing Record 32 of Set 7 | haizhou
# Processing Record 33 of Set 7 | forest hill
# Processing Record 34 of Set 7 | fortuna
# Processing Record 35 of Set 7 | sorland
# Processing Record 36 of Set 7 | pochutla
# Processing Record 37 of Set 7 | lasa
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | lahaina
# Processing Record 40 of Set 7 | puerto escondido
# Processing Record 41 of Set 7 | ternate
# Processing Record 42 of Set 7 | hualmay
# Processing Record 43 of Set 7 | fethiye
# Processing Record 44 of Set 7 | sheridan
# Processing Record 45 of Set 7 | qiryat shemona
# Processing Record 46 of Set 7 | zyryanka
# Processing Record 47 of Set 7 | vokhma
# Processing Record 48 of Set 7 | candido mendes
# Processing Record 49 of Set 7 | lolua
# City not found.  Skipping...
# Processing Record 50 of Set 7 | lyantonde
# Processing Record 1 of Set 8 | hun
# Processing Record 2 of Set 8 | gabu
# Processing Record 3 of Set 8 | tarauaca
# Processing Record 4 of Set 8 | kindu
# Processing Record 5 of Set 8 | solvychegodsk
# Processing Record 6 of Set 8 | christchurch
# Processing Record 7 of Set 8 | mingguang
# Processing Record 8 of Set 8 | yarada
# Processing Record 9 of Set 8 | faya
# Processing Record 10 of Set 8 | hofn
# Processing Record 11 of Set 8 | tigre
# Processing Record 12 of Set 8 | duncan
# Processing Record 13 of Set 8 | fukue
# Processing Record 14 of Set 8 | safaga
# Processing Record 15 of Set 8 | vung tau
# Processing Record 16 of Set 8 | rungata
# City not found.  Skipping...
# Processing Record 17 of Set 8 | pangkalanbuun
# Processing Record 18 of Set 8 | fairbanks
# Processing Record 19 of Set 8 | shenjiamen
# Processing Record 20 of Set 8 | castletown
# Processing Record 21 of Set 8 | zhezkazgan
# Processing Record 22 of Set 8 | pila
# Processing Record 23 of Set 8 | aklavik
# Processing Record 24 of Set 8 | le port
# Processing Record 25 of Set 8 | dong hoi
# Processing Record 26 of Set 8 | liku
# Processing Record 27 of Set 8 | port blair
# Processing Record 28 of Set 8 | katobu
# Processing Record 29 of Set 8 | gorno-chuyskiy
# City not found.  Skipping...
# Processing Record 30 of Set 8 | naliya
# Processing Record 31 of Set 8 | alekseyevka
# Processing Record 32 of Set 8 | biak
# Processing Record 33 of Set 8 | san andres
# Processing Record 34 of Set 8 | pemba
# Processing Record 35 of Set 8 | nenjiang
# Processing Record 36 of Set 8 | ahuimanu
# Processing Record 37 of Set 8 | rodrigues alves
# Processing Record 38 of Set 8 | haines junction
# Processing Record 39 of Set 8 | baykit
# Processing Record 40 of Set 8 | odweyne
# Processing Record 41 of Set 8 | mount gambier
# Processing Record 42 of Set 8 | norrtalje
# Processing Record 43 of Set 8 | la libertad
# Processing Record 44 of Set 8 | udachnyy
# Processing Record 45 of Set 8 | bajil
# Processing Record 46 of Set 8 | san jose
# Processing Record 47 of Set 8 | kaeo
# Processing Record 48 of Set 8 | atlantic beach
# Processing Record 49 of Set 8 | kruisfontein
# Processing Record 50 of Set 8 | keti bandar
# Processing Record 1 of Set 9 | monrovia
# Processing Record 2 of Set 9 | yulara
# Processing Record 3 of Set 9 | skiros
# City not found.  Skipping...
# Processing Record 4 of Set 9 | ihosy
# Processing Record 5 of Set 9 | grafenhainichen
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | kiruna
# Processing Record 8 of Set 9 | tubruq
# City not found.  Skipping...
# Processing Record 9 of Set 9 | mayor pablo lagerenza
# Processing Record 10 of Set 9 | shache
# Processing Record 11 of Set 9 | aasiaat
# Processing Record 12 of Set 9 | xichang
# Processing Record 13 of Set 9 | saleaula
# City not found.  Skipping...
# Processing Record 14 of Set 9 | santa rosa
# Processing Record 15 of Set 9 | nedryhayliv
# Processing Record 16 of Set 9 | high level
# Processing Record 17 of Set 9 | methoni
# Processing Record 18 of Set 9 | ayan
# Processing Record 19 of Set 9 | san miguelito
# Processing Record 20 of Set 9 | vangaindrano
# Processing Record 21 of Set 9 | aitape
# Processing Record 22 of Set 9 | nanortalik
# Processing Record 23 of Set 9 | ekhabi
# Processing Record 24 of Set 9 | ahipara
# Processing Record 25 of Set 9 | general roca
# Processing Record 26 of Set 9 | wodonga
# Processing Record 27 of Set 9 | clyde river
# Processing Record 28 of Set 9 | tkvarcheli
# City not found.  Skipping...
# Processing Record 29 of Set 9 | honiara
# Processing Record 30 of Set 9 | wuning
# Processing Record 31 of Set 9 | hirado
# Processing Record 32 of Set 9 | viedma
# Processing Record 33 of Set 9 | chaiyaphum
# Processing Record 34 of Set 9 | rudiskes
# Processing Record 35 of Set 9 | plettenberg bay
# Processing Record 36 of Set 9 | egvekinot
# Processing Record 37 of Set 9 | werda
# Processing Record 38 of Set 9 | vestmannaeyjar
# Processing Record 39 of Set 9 | mana
# Processing Record 40 of Set 9 | nicoya
# Processing Record 41 of Set 9 | antofagasta
# Processing Record 42 of Set 9 | waipawa
# Processing Record 43 of Set 9 | vila franca do campo
# Processing Record 44 of Set 9 | nemuro
# Processing Record 45 of Set 9 | porto novo
# Processing Record 46 of Set 9 | la asuncion
# Processing Record 47 of Set 9 | lipin bor
# Processing Record 48 of Set 9 | pisco
# Processing Record 49 of Set 9 | mahebourg
# Processing Record 50 of Set 9 | longhua
# Processing Record 1 of Set 10 | wattegama
# Processing Record 2 of Set 10 | gunjur
# Processing Record 3 of Set 10 | dharchula
# Processing Record 4 of Set 10 | katiola
# Processing Record 5 of Set 10 | wewak
# Processing Record 6 of Set 10 | shetpe
# Processing Record 7 of Set 10 | kualakapuas
# Processing Record 8 of Set 10 | nago
# Processing Record 9 of Set 10 | southbridge
# Processing Record 10 of Set 10 | port hedland
# Processing Record 11 of Set 10 | cusset
# Processing Record 12 of Set 10 | matara
# Processing Record 13 of Set 10 | sulangan
# Processing Record 14 of Set 10 | manjeshwar
# Processing Record 15 of Set 10 | batemans bay
# Processing Record 16 of Set 10 | boa viagem
# Processing Record 17 of Set 10 | capoterra
# Processing Record 18 of Set 10 | manacapuru
# Processing Record 19 of Set 10 | horsham
# Processing Record 20 of Set 10 | tiksi
# Processing Record 21 of Set 10 | iseyin
# Processing Record 22 of Set 10 | graham
# Processing Record 23 of Set 10 | quatre cocos
# Processing Record 24 of Set 10 | san carlos de bariloche
# Processing Record 25 of Set 10 | kropotkin
# Processing Record 26 of Set 10 | broken hill
# Processing Record 27 of Set 10 | hami
# Processing Record 28 of Set 10 | constantine
# Processing Record 29 of Set 10 | coahuayana
# Processing Record 30 of Set 10 | texarkana
# Processing Record 31 of Set 10 | kyra
# Processing Record 32 of Set 10 | makakilo city
# Processing Record 33 of Set 10 | freeport
# Processing Record 34 of Set 10 | bintulu
# Processing Record 35 of Set 10 | sakakah
# Processing Record 36 of Set 10 | huron
# Processing Record 37 of Set 10 | tecoanapa
# Processing Record 38 of Set 10 | holme
# Processing Record 39 of Set 10 | banjar
# Processing Record 40 of Set 10 | zhangjiakou
# Processing Record 41 of Set 10 | mayo
# Processing Record 42 of Set 10 | cidreira
# Processing Record 43 of Set 10 | turan
# Processing Record 44 of Set 10 | garowe
# Processing Record 45 of Set 10 | swakopmund
# Processing Record 46 of Set 10 | te anau
# Processing Record 47 of Set 10 | rabak
# Processing Record 48 of Set 10 | darhan
# Processing Record 49 of Set 10 | sao jose da coroa grande
# Processing Record 50 of Set 10 | balabac
# Processing Record 1 of Set 11 | saint-augustin
# Processing Record 2 of Set 11 | broome
# Processing Record 3 of Set 11 | pacific grove
# Processing Record 4 of Set 11 | santa maria
# Processing Record 5 of Set 11 | sao felix do xingu
# Processing Record 6 of Set 11 | sept-iles
# Processing Record 7 of Set 11 | quimper
# Processing Record 8 of Set 11 | baruun-urt
# Processing Record 9 of Set 11 | emerald
# Processing Record 10 of Set 11 | camalu
# Processing Record 11 of Set 11 | tepic
# Processing Record 12 of Set 11 | sayyan
# Processing Record 13 of Set 11 | inhambane
# Processing Record 14 of Set 11 | mizan teferi
# Processing Record 15 of Set 11 | saint-prosper
# Processing Record 16 of Set 11 | robe
# Processing Record 17 of Set 11 | tecalitlan
# Processing Record 18 of Set 11 | verkhnevilyuysk
# Processing Record 19 of Set 11 | along
# Processing Record 20 of Set 11 | coquimbo
# Processing Record 21 of Set 11 | madang
# Processing Record 22 of Set 11 | sorvag
# City not found.  Skipping...
# Processing Record 23 of Set 11 | carupano
# Processing Record 24 of Set 11 | banon
# Processing Record 25 of Set 11 | hirara
# Processing Record 26 of Set 11 | sabinas hidalgo
# Processing Record 27 of Set 11 | maragogi
# Processing Record 28 of Set 11 | umm kaddadah
# Processing Record 29 of Set 11 | cabra
# Processing Record 30 of Set 11 | petauke
# Processing Record 31 of Set 11 | novyy urengoy
# Processing Record 32 of Set 11 | cacador
# Processing Record 33 of Set 11 | nguiu
# City not found.  Skipping...
# Processing Record 34 of Set 11 | ketchenery
# City not found.  Skipping...
# Processing Record 35 of Set 11 | ribeira grande
# Processing Record 36 of Set 11 | sokoto
# Processing Record 37 of Set 11 | port keats
# Processing Record 38 of Set 11 | nantucket
# Processing Record 39 of Set 11 | verkhoyansk
# Processing Record 40 of Set 11 | seminole
# Processing Record 41 of Set 11 | tumannyy
# City not found.  Skipping...
# Processing Record 42 of Set 11 | arraias
# Processing Record 43 of Set 11 | myitkyina
# Processing Record 44 of Set 11 | luanda
# Processing Record 45 of Set 11 | harper
# Processing Record 46 of Set 11 | umzimvubu
# City not found.  Skipping...
# Processing Record 47 of Set 11 | warqla
# City not found.  Skipping...
# Processing Record 48 of Set 11 | lugo
# Processing Record 49 of Set 11 | nassjo
# Processing Record 50 of Set 11 | shintomi
# Processing Record 1 of Set 12 | redlands
# Processing Record 2 of Set 12 | rocha
# Processing Record 3 of Set 12 | sangar
# Processing Record 4 of Set 12 | bilma
# Processing Record 5 of Set 12 | daru
# Processing Record 6 of Set 12 | komsomolskiy
# Processing Record 7 of Set 12 | godeanu
# Processing Record 8 of Set 12 | nkhata bay
# Processing Record 9 of Set 12 | okato
# Processing Record 10 of Set 12 | burgeo
# Processing Record 11 of Set 12 | adrar
# Processing Record 12 of Set 12 | charlestown
# Processing Record 13 of Set 12 | egra
# Processing Record 14 of Set 12 | linden
# Processing Record 15 of Set 12 | chapais
# Processing Record 16 of Set 12 | miraflores
# Processing Record 17 of Set 12 | sula
# Processing Record 18 of Set 12 | champaign
# Processing Record 19 of Set 12 | imbituba
# Processing Record 20 of Set 12 | presidente medici
# Processing Record 21 of Set 12 | zhigansk
# Processing Record 22 of Set 12 | soyo
# Processing Record 23 of Set 12 | sosua
# Processing Record 24 of Set 12 | ambovombe
# Processing Record 25 of Set 12 | zhanatas
# City not found.  Skipping...
# Processing Record 26 of Set 12 | vengerovo
# Processing Record 27 of Set 12 | heyang
# Processing Record 28 of Set 12 | glace bay
# Processing Record 29 of Set 12 | kijang
# Processing Record 30 of Set 12 | kholodnyy
# Processing Record 31 of Set 12 | roald
# Processing Record 32 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 12 | arman
# Processing Record 34 of Set 12 | bafq
# Processing Record 35 of Set 12 | alasehir
# Processing Record 36 of Set 12 | vila do maio
# Processing Record 37 of Set 12 | brooks
# Processing Record 38 of Set 12 | buala
# Processing Record 39 of Set 12 | ondangwa
# Processing Record 40 of Set 12 | shaunavon
# Processing Record 41 of Set 12 | mont-dore
# Processing Record 42 of Set 12 | kortkeros
# Processing Record 43 of Set 12 | morro bay
# Processing Record 44 of Set 12 | saint-joseph
# Processing Record 45 of Set 12 | sainte-anne-des-monts
# Processing Record 46 of Set 12 | ko samui
# Processing Record 47 of Set 12 | fairview
# Processing Record 48 of Set 12 | bolungarvik
# City not found.  Skipping...
# Processing Record 49 of Set 12 | leninsk
# Processing Record 50 of Set 12 | san javier
# Processing Record 1 of Set 13 | bayan
# Processing Record 2 of Set 13 | churapcha
# Processing Record 3 of Set 13 | noumea
# Processing Record 4 of Set 13 | marsa matruh
# Processing Record 5 of Set 13 | pagman
# City not found.  Skipping...
# Processing Record 6 of Set 13 | galgani
# City not found.  Skipping...
# Processing Record 7 of Set 13 | elmira
# Processing Record 8 of Set 13 | bukachacha
# Processing Record 9 of Set 13 | uspenka
# Processing Record 10 of Set 13 | ust-nera
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | melchor de mencos
# Processing Record 13 of Set 13 | bagan
# Processing Record 14 of Set 13 | toamasina
# Processing Record 15 of Set 13 | toliary
# City not found.  Skipping...
# Processing Record 16 of Set 13 | raozan
# City not found.  Skipping...
# Processing Record 17 of Set 13 | urucara
# Processing Record 18 of Set 13 | fort nelson
# Processing Record 19 of Set 13 | kuzino
# Processing Record 20 of Set 13 | eureka
# Processing Record 21 of Set 13 | lalibela
# Processing Record 22 of Set 13 | tezu
# Processing Record 23 of Set 13 | ewo
# Processing Record 24 of Set 13 | falmouth
# Processing Record 25 of Set 13 | sambava
# Processing Record 26 of Set 13 | dali
# Processing Record 27 of Set 13 | atambua
# Processing Record 28 of Set 13 | bathsheba
# Processing Record 29 of Set 13 | nizhneyansk
# City not found.  Skipping...
# Processing Record 30 of Set 13 | labuhan
# Processing Record 31 of Set 13 | kazalinsk
# City not found.  Skipping...
# Processing Record 32 of Set 13 | kutum
# Processing Record 33 of Set 13 | fuyu
# Processing Record 34 of Set 13 | caxito
# Processing Record 35 of Set 13 | mangan
# Processing Record 36 of Set 13 | la colorada
# Processing Record 37 of Set 13 | aksu
# Processing Record 38 of Set 13 | nouadhibou
# Processing Record 39 of Set 13 | kasongo-lunda
# Processing Record 40 of Set 13 | necochea
# Processing Record 41 of Set 13 | borshchiv
# Processing Record 42 of Set 13 | bakau
# Processing Record 43 of Set 13 | san quintin
# Processing Record 44 of Set 13 | bar harbor
# Processing Record 45 of Set 13 | sioux lookout
# Processing Record 46 of Set 13 | ketchikan
# Processing Record 47 of Set 13 | bundaberg
# Processing Record 48 of Set 13 | mazatlan
# Processing Record 49 of Set 13 | shingu
# Processing Record 50 of Set 13 | lethem
# Processing Record 1 of Set 14 | taoudenni
# Processing Record 2 of Set 14 | tandalti
# Processing Record 3 of Set 14 | ilebo
# Processing Record 4 of Set 14 | san policarpo
# Processing Record 5 of Set 14 | tazovskiy
# Processing Record 6 of Set 14 | nurota
# Processing Record 7 of Set 14 | sechura
# Processing Record 8 of Set 14 | wanning
# Processing Record 9 of Set 14 | novo aripuana
# Processing Record 10 of Set 14 | presidencia roque saenz pena
# Processing Record 11 of Set 14 | stokmarknes
# Processing Record 12 of Set 14 | jaora
# Processing Record 13 of Set 14 | kerur
# Processing Record 14 of Set 14 | dwarka
# Processing Record 15 of Set 14 | abu kamal
# Processing Record 16 of Set 14 | naze
# Processing Record 17 of Set 14 | atocha
# Processing Record 18 of Set 14 | ardistan
# City not found.  Skipping...
# Processing Record 19 of Set 14 | fort saint john
# City not found.  Skipping...
# Processing Record 20 of Set 14 | paamiut
# Processing Record 21 of Set 14 | midland
# Processing Record 22 of Set 14 | calama
# Processing Record 23 of Set 14 | kuche
# City not found.  Skipping...
# Processing Record 24 of Set 14 | luganville
# Processing Record 25 of Set 14 | mitu
# Processing Record 26 of Set 14 | qinhuangdao
# Processing Record 27 of Set 14 | tual
# Processing Record 28 of Set 14 | laurinburg
# Processing Record 29 of Set 14 | rio grande
# Processing Record 30 of Set 14 | washington
# Processing Record 31 of Set 14 | vostok
# Processing Record 32 of Set 14 | novyy oskol
# Processing Record 33 of Set 14 | goderich
# Processing Record 34 of Set 14 | dungarpur
# Processing Record 35 of Set 14 | liuli
# Processing Record 36 of Set 14 | panna
# Processing Record 37 of Set 14 | ndjole
# Processing Record 38 of Set 14 | gumushane
# City not found.  Skipping...
# Processing Record 39 of Set 14 | la rioja
# Processing Record 40 of Set 14 | mogadishu
# Processing Record 41 of Set 14 | darnah
# Processing Record 42 of Set 14 | sokoni
# Processing Record 43 of Set 14 | meaford
# Processing Record 44 of Set 14 | iranshahr
# Processing Record 45 of Set 14 | cabadiangan
# Processing Record 46 of Set 14 | port-cartier
# Processing Record 47 of Set 14 | kedrovyy
# Processing Record 48 of Set 14 | skovorodino
# Processing Record 49 of Set 14 | nuevo casas grandes
# Processing Record 50 of Set 14 | juneau
# Processing Record 1 of Set 15 | mrirt
# City not found.  Skipping...
# Processing Record 2 of Set 15 | samarai
# Processing Record 3 of Set 15 | cabras
# Processing Record 4 of Set 15 | tsogni
# Processing Record 5 of Set 15 | acapulco
# Processing Record 6 of Set 15 | raudeberg
# Processing Record 7 of Set 15 | ercis
# Processing Record 8 of Set 15 | uvira
# Processing Record 9 of Set 15 | tingo maria
# Processing Record 10 of Set 15 | orcopampa
# Processing Record 11 of Set 15 | lebedinyy
# Processing Record 12 of Set 15 | pekalongan
# Processing Record 13 of Set 15 | krasnyy klyuch
# Processing Record 14 of Set 15 | pailon
# Processing Record 15 of Set 15 | westerland
# Processing Record 16 of Set 15 | cayenne
# Processing Record 17 of Set 15 | fuxin
# Processing Record 18 of Set 15 | galesong
# Processing Record 19 of Set 15 | tahta
# Processing Record 20 of Set 15 | nampula
# Processing Record 21 of Set 15 | mogok
# Processing Record 22 of Set 15 | kanigiri
# Processing Record 23 of Set 15 | katima mulilo
# Processing Record 24 of Set 15 | marystown
# Processing Record 25 of Set 15 | ituni
# City not found.  Skipping...
# Processing Record 26 of Set 15 | lerwick
# Processing Record 27 of Set 15 | laguna
# Processing Record 28 of Set 15 | diu
# Processing Record 29 of Set 15 | auki
# Processing Record 30 of Set 15 | kemi
# Processing Record 31 of Set 15 | dudinka
# Processing Record 32 of Set 15 | dukat
# Processing Record 33 of Set 15 | sotouboua
# Processing Record 34 of Set 15 | guia de isora
# Processing Record 35 of Set 15 | lukovetskiy
# Processing Record 36 of Set 15 | tyup
# Processing Record 37 of Set 15 | ulladulla
# Processing Record 38 of Set 15 | skagastrond
# City not found.  Skipping...
# Processing Record 39 of Set 15 | la orilla
# Processing Record 40 of Set 15 | isangel
# ------------------------------
# Date retrieval complete
# ------------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 684

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Khatanga  71.9667  102.5000    -50.55        76          50
# 1     Jablanica  43.6603   17.7617     37.40        44          20
# 2       Iquitos  -3.7481  -73.2472     75.20        94          90
# 3        Atuona  -9.8000 -139.0333     77.43        77          18
# 4         Kunda  25.7167   81.5167     45.05        62           8
# 5        Tutoia  -2.7619  -42.2744     79.99        80          93
# 6           Vao -22.6667  167.4833     76.86        92         100
# 7        Barrow  71.2906 -156.7887    -11.20        77           1
# 8        Usinsk  65.9939   57.5281    -16.15        86         100
# 9  Punta Arenas -53.1500  -70.9167     55.40        71           0
#
#    Wind Speed Country                 Date       Description
# 0        1.52      RU  2021-01-14 23:46:55  scattered clouds
# 1       14.97      BA  2021-01-14 23:46:55        few clouds
# 2        8.05      PE  2021-01-14 23:46:55     moderate rain
# 3       13.18      PF  2021-01-14 23:46:55        few clouds
# 4        2.89      IN  2021-01-14 23:46:55         clear sky
# 5       14.34      BR  2021-01-14 23:46:56   overcast clouds
# 6       11.14      NC  2021-01-14 23:46:56   overcast clouds
# 7       13.80      US  2021-01-14 23:45:04         clear sky
# 8        5.57      RU  2021-01-14 23:46:56   overcast clouds
# 9       12.66      CL  2021-01-14 23:43:30         clear sky

# %%
# Create the CSV output file
output_data_file = "../Weather_Database/WeatherPy_Database.csv"

# Export city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
