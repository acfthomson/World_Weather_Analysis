# %% [markdown]
# ## Deliverable 1. Retrieve Weather Data

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %%
# Generate random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# When this cell is executed, the output is a zip object in memory
# The zip object packs each pair of lats and longs having the same index in their respective array
# into a tuple

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import citipy module
from citipy import citipy

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 761

# %%
# Map out how to get weather data for each city for the website
# 1. Import dependencies and initialize counters and an empty list that will hold the weather data
# 2. Loop through the cities list
# 3. Group the cities in set of 50 to log the process as weather data is found for each city
    # Two counters will be needed: one to log the city count from 1 to 50 and another for the sets
# 4. Build the city_url or endpoint for each city
# 5. Log the URL and the record and set numbers
# 6. Make an API request for each city
# 7. Parse the JSON weather data for the following:
    # City, country, and date
    # Latitude and longitude
    # Maximum temperature
    # Humidity
    # Cloudiness
    # Wind speed
# 8. Add the data to a list in a dictionary format and then convert the list to a DataFrame

# %%
# Import the requests library
import requests

# Import the API key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d58cec1399a9bffb48701a67c798162c

# %%
# Import the datetime module from the datetime library
from datetime import datetime

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning of data retrieval          ")
print("-------------------------------------")

# Create the counters and initialize to 1 because the first iteration of logging for each recorded response and
# the set needs to start at 1
record_count = 1
set_count = 1


# Every time a city is referenced in the code, the index on the cities list needs to be used
# This will cause programming errors when building city_url because it adds to the index, not the city name to
# city_url
# To fix this issue, another for loop needs to be created in order to the city from the cities list
# Instead of using two for loops, use the enumerate() method as an alternative way to iterate through the list 
# of cities and retrieve both the index and city from the list

# Loop through the cities in the list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Add a try-except block to prevent API requests from stopping prematurelyy if the city_weather requests is 
# not a valuid request
# If the request isn't valid, the code ill not find the first item requested, which is the dictionary "coord"
# The code will skip the city and continue to run

# Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve the data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information to the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})
        
# If an error is given, skip the city
    except:
        print("City not found.  Skipping...")
        pass
    
# Indicate the date loading is complete
print("------------------------------")
print("Date retrieval complete       ")
print("------------------------------")
# Out:
# Beginning of data retrieval
# -------------------------------------
# Processing Record 1 of Set 1 | valdivia
# Processing Record 2 of Set 1 | bredasdorp
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | leningradskiy
# Processing Record 5 of Set 1 | khasan
# Processing Record 6 of Set 1 | vila franca do campo
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | quatre cocos
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | kodiak
# Processing Record 11 of Set 1 | midland
# Processing Record 12 of Set 1 | cherskiy
# Processing Record 13 of Set 1 | togur
# Processing Record 14 of Set 1 | blonduos
# City not found.  Skipping...
# Processing Record 15 of Set 1 | shasta lake
# Processing Record 16 of Set 1 | sorvag
# City not found.  Skipping...
# Processing Record 17 of Set 1 | itarema
# Processing Record 18 of Set 1 | nikolskoye
# Processing Record 19 of Set 1 | padang
# Processing Record 20 of Set 1 | tiarei
# Processing Record 21 of Set 1 | barrow
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | tsihombe
# City not found.  Skipping...
# Processing Record 24 of Set 1 | avarua
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | norman wells
# Processing Record 27 of Set 1 | veraval
# Processing Record 28 of Set 1 | ponta do sol
# Processing Record 29 of Set 1 | clyde river
# Processing Record 30 of Set 1 | touros
# Processing Record 31 of Set 1 | katsiveli
# City not found.  Skipping...
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | noshiro
# Processing Record 35 of Set 1 | pevek
# Processing Record 36 of Set 1 | nanortalik
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | lososina
# Processing Record 39 of Set 1 | mar del plata
# Processing Record 40 of Set 1 | bluff
# Processing Record 41 of Set 1 | mtambile
# Processing Record 42 of Set 1 | cabo san lucas
# Processing Record 43 of Set 1 | severnyy
# Processing Record 44 of Set 1 | galle
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | north bend
# Processing Record 47 of Set 1 | longyearbyen
# Processing Record 48 of Set 1 | jatai
# Processing Record 49 of Set 1 | hilo
# Processing Record 50 of Set 1 | mataura
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | tuatapere
# Processing Record 3 of Set 2 | mortka
# Processing Record 4 of Set 2 | bathsheba
# Processing Record 5 of Set 2 | ushuaia
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | severo-kurilsk
# Processing Record 8 of Set 2 | tasiilaq
# Processing Record 9 of Set 2 | bethel
# Processing Record 10 of Set 2 | gladstone
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | belyye berega
# Processing Record 13 of Set 2 | geraldton
# Processing Record 14 of Set 2 | airai
# Processing Record 15 of Set 2 | bambous virieux
# Processing Record 16 of Set 2 | palu
# Processing Record 17 of Set 2 | carnarvon
# Processing Record 18 of Set 2 | varkaus
# Processing Record 19 of Set 2 | avera
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | puruandiro
# Processing Record 22 of Set 2 | anadyr
# Processing Record 23 of Set 2 | cape town
# Processing Record 24 of Set 2 | tulcingo
# City not found.  Skipping...
# Processing Record 25 of Set 2 | tuktoyaktuk
# Processing Record 26 of Set 2 | chilca
# Processing Record 27 of Set 2 | saint george
# Processing Record 28 of Set 2 | chiriguana
# Processing Record 29 of Set 2 | hobyo
# Processing Record 30 of Set 2 | port alfred
# Processing Record 31 of Set 2 | cidreira
# Processing Record 32 of Set 2 | meulaboh
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | kargala
# Processing Record 35 of Set 2 | aguimes
# Processing Record 36 of Set 2 | terrace bay
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | asau
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | altamura
# Processing Record 42 of Set 2 | butaritari
# Processing Record 43 of Set 2 | tautira
# Processing Record 44 of Set 2 | new norfolk
# Processing Record 45 of Set 2 | port elizabeth
# Processing Record 46 of Set 2 | dingle
# Processing Record 47 of Set 2 | taolanaro
# City not found.  Skipping...
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | poltava
# Processing Record 50 of Set 2 | pimentel
# Processing Record 1 of Set 3 | chatellerault
# Processing Record 2 of Set 3 | saskylakh
# Processing Record 3 of Set 3 | sitka
# Processing Record 4 of Set 3 | apac
# Processing Record 5 of Set 3 | elizabeth city
# Processing Record 6 of Set 3 | la ronge
# Processing Record 7 of Set 3 | albany
# Processing Record 8 of Set 3 | noyabrsk
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | sulangan
# Processing Record 11 of Set 3 | belushya guba
# City not found.  Skipping...
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | zabaykalsk
# Processing Record 14 of Set 3 | torbay
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | bria
# Processing Record 18 of Set 3 | fortuna
# Processing Record 19 of Set 3 | bengkulu
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | atar
# Processing Record 22 of Set 3 | paamiut
# Processing Record 23 of Set 3 | shubarkuduk
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | acajutla
# Processing Record 26 of Set 3 | mount isa
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | namatanai
# Processing Record 29 of Set 3 | georgetown
# Processing Record 30 of Set 3 | vaitupu
# City not found.  Skipping...
# Processing Record 31 of Set 3 | mehamn
# Processing Record 32 of Set 3 | junnar
# Processing Record 33 of Set 3 | itoman
# Processing Record 34 of Set 3 | varnavino
# Processing Record 35 of Set 3 | tutin
# Processing Record 36 of Set 3 | ishigaki
# Processing Record 37 of Set 3 | clacton-on-sea
# Processing Record 38 of Set 3 | gat
# Processing Record 39 of Set 3 | san quintin
# Processing Record 40 of Set 3 | constitucion
# Processing Record 41 of Set 3 | umzimvubu
# City not found.  Skipping...
# Processing Record 42 of Set 3 | shanghai
# Processing Record 43 of Set 3 | harper
# Processing Record 44 of Set 3 | attawapiskat
# City not found.  Skipping...
# Processing Record 45 of Set 3 | moose factory
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | webuye
# Processing Record 48 of Set 3 | senmonorom
# City not found.  Skipping...
# Processing Record 49 of Set 3 | tarves
# Processing Record 50 of Set 3 | paraiso
# Processing Record 1 of Set 4 | saint-francois
# Processing Record 2 of Set 4 | faanui
# Processing Record 3 of Set 4 | rebrikha
# Processing Record 4 of Set 4 | puerto narino
# Processing Record 5 of Set 4 | pitimbu
# Processing Record 6 of Set 4 | stornoway
# Processing Record 7 of Set 4 | nizhneyansk
# City not found.  Skipping...
# Processing Record 8 of Set 4 | kijang
# Processing Record 9 of Set 4 | kalmunai
# Processing Record 10 of Set 4 | sayville
# Processing Record 11 of Set 4 | azare
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | makakilo city
# Processing Record 14 of Set 4 | zeya
# Processing Record 15 of Set 4 | tukrah
# Processing Record 16 of Set 4 | quang ngai
# Processing Record 17 of Set 4 | svetlaya
# Processing Record 18 of Set 4 | nanakuli
# Processing Record 19 of Set 4 | tazmalt
# Processing Record 20 of Set 4 | chokurdakh
# Processing Record 21 of Set 4 | lompoc
# Processing Record 22 of Set 4 | lavrentiya
# Processing Record 23 of Set 4 | mahebourg
# Processing Record 24 of Set 4 | vila velha
# Processing Record 25 of Set 4 | watertown
# Processing Record 26 of Set 4 | sombrio
# Processing Record 27 of Set 4 | mount gambier
# Processing Record 28 of Set 4 | iquique
# Processing Record 29 of Set 4 | flin flon
# Processing Record 30 of Set 4 | brae
# Processing Record 31 of Set 4 | tual
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | kapaa
# Processing Record 34 of Set 4 | awjilah
# Processing Record 35 of Set 4 | barth
# Processing Record 36 of Set 4 | saldanha
# Processing Record 37 of Set 4 | marawi
# Processing Record 38 of Set 4 | boissevain
# Processing Record 39 of Set 4 | bac can
# City not found.  Skipping...
# Processing Record 40 of Set 4 | shumskiy
# Processing Record 41 of Set 4 | merrill
# Processing Record 42 of Set 4 | amealco
# Processing Record 43 of Set 4 | ust-kuyga
# Processing Record 44 of Set 4 | charters towers
# Processing Record 45 of Set 4 | iqaluit
# Processing Record 46 of Set 4 | tres palos
# Processing Record 47 of Set 4 | illoqqortoormiut
# City not found.  Skipping...
# Processing Record 48 of Set 4 | sentyabrskiy
# City not found.  Skipping...
# Processing Record 49 of Set 4 | pingliang
# Processing Record 50 of Set 4 | samusu
# City not found.  Skipping...
# Processing Record 1 of Set 5 | saint-pierre
# Processing Record 2 of Set 5 | igbo ora
# Processing Record 3 of Set 5 | camacha
# Processing Record 4 of Set 5 | tiznit
# Processing Record 5 of Set 5 | loreto
# Processing Record 6 of Set 5 | rauma
# Processing Record 7 of Set 5 | tosno
# Processing Record 8 of Set 5 | makubetsu
# Processing Record 9 of Set 5 | saint-philippe
# Processing Record 10 of Set 5 | kaeo
# Processing Record 11 of Set 5 | beyneu
# Processing Record 12 of Set 5 | abalak
# Processing Record 13 of Set 5 | kailua
# Processing Record 14 of Set 5 | tabriz
# Processing Record 15 of Set 5 | nome
# Processing Record 16 of Set 5 | chagoda
# Processing Record 17 of Set 5 | kiama
# Processing Record 18 of Set 5 | hohhot
# Processing Record 19 of Set 5 | belmonte
# Processing Record 20 of Set 5 | dikson
# Processing Record 21 of Set 5 | pacific grove
# Processing Record 22 of Set 5 | datong
# Processing Record 23 of Set 5 | bardiyah
# Processing Record 24 of Set 5 | general pico
# Processing Record 25 of Set 5 | sur
# Processing Record 26 of Set 5 | kysyl-syr
# Processing Record 27 of Set 5 | rockport
# Processing Record 28 of Set 5 | lorengau
# Processing Record 29 of Set 5 | kahului
# Processing Record 30 of Set 5 | zhigansk
# Processing Record 31 of Set 5 | cockburn town
# Processing Record 32 of Set 5 | kaura namoda
# Processing Record 33 of Set 5 | aklavik
# Processing Record 34 of Set 5 | thompson
# Processing Record 35 of Set 5 | gillette
# Processing Record 36 of Set 5 | grand centre
# City not found.  Skipping...
# Processing Record 37 of Set 5 | amderma
# City not found.  Skipping...
# Processing Record 38 of Set 5 | thunder bay
# Processing Record 39 of Set 5 | ixhuatan
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | ilulissat
# Processing Record 42 of Set 5 | bud
# Processing Record 43 of Set 5 | barentsburg
# City not found.  Skipping...
# Processing Record 44 of Set 5 | strelka
# Processing Record 45 of Set 5 | jubayl
# City not found.  Skipping...
# Processing Record 46 of Set 5 | goundam
# Processing Record 47 of Set 5 | kralendijk
# Processing Record 48 of Set 5 | rio gallegos
# Processing Record 49 of Set 5 | fernie
# Processing Record 50 of Set 5 | nishihara
# Processing Record 1 of Set 6 | puri
# Processing Record 2 of Set 6 | viligili
# City not found.  Skipping...
# Processing Record 3 of Set 6 | kalaleh
# Processing Record 4 of Set 6 | taoudenni
# Processing Record 5 of Set 6 | san patricio
# Processing Record 6 of Set 6 | sargur
# Processing Record 7 of Set 6 | santa cruz del sur
# Processing Record 8 of Set 6 | ngaoundere
# Processing Record 9 of Set 6 | yunjinghong
# City not found.  Skipping...
# Processing Record 10 of Set 6 | pavlodar
# Processing Record 11 of Set 6 | porangatu
# Processing Record 12 of Set 6 | show low
# Processing Record 13 of Set 6 | ancud
# Processing Record 14 of Set 6 | los llanos de aridane
# Processing Record 15 of Set 6 | omsukchan
# Processing Record 16 of Set 6 | benicarlo
# Processing Record 17 of Set 6 | ahipara
# Processing Record 18 of Set 6 | arraial do cabo
# Processing Record 19 of Set 6 | constantine
# Processing Record 20 of Set 6 | launceston
# Processing Record 21 of Set 6 | rundu
# Processing Record 22 of Set 6 | zhangjiakou
# Processing Record 23 of Set 6 | egvekinot
# Processing Record 24 of Set 6 | chanute
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | merauke
# Processing Record 27 of Set 6 | trairi
# Processing Record 28 of Set 6 | wasilla
# Processing Record 29 of Set 6 | tuy hoa
# Processing Record 30 of Set 6 | mira
# Processing Record 31 of Set 6 | khuzdar
# Processing Record 32 of Set 6 | ambam
# Processing Record 33 of Set 6 | bucak
# Processing Record 34 of Set 6 | ishinomaki
# Processing Record 35 of Set 6 | miranorte
# City not found.  Skipping...
# Processing Record 36 of Set 6 | bakel
# Processing Record 37 of Set 6 | salalah
# Processing Record 38 of Set 6 | teguise
# Processing Record 39 of Set 6 | manokwari
# Processing Record 40 of Set 6 | milingimbi
# City not found.  Skipping...
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | cukai
# Processing Record 43 of Set 6 | chkalovsk
# Processing Record 44 of Set 6 | kyshtovka
# Processing Record 45 of Set 6 | cayenne
# Processing Record 46 of Set 6 | chunoyar
# Processing Record 47 of Set 6 | dharchula
# Processing Record 48 of Set 6 | hofn
# Processing Record 49 of Set 6 | morondava
# Processing Record 50 of Set 6 | lolua
# City not found.  Skipping...
# Processing Record 1 of Set 7 | terrace
# Processing Record 2 of Set 7 | knysna
# Processing Record 3 of Set 7 | santa marta
# Processing Record 4 of Set 7 | aripuana
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | gorin
# Processing Record 7 of Set 7 | uyuni
# Processing Record 8 of Set 7 | sept-iles
# Processing Record 9 of Set 7 | ozgon
# City not found.  Skipping...
# Processing Record 10 of Set 7 | ritchie
# Processing Record 11 of Set 7 | aflu
# City not found.  Skipping...
# Processing Record 12 of Set 7 | pihuamo
# Processing Record 13 of Set 7 | acapulco
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | codrington
# Processing Record 16 of Set 7 | nioro
# Processing Record 17 of Set 7 | duldurga
# Processing Record 18 of Set 7 | mokhotlong
# Processing Record 19 of Set 7 | aktau
# Processing Record 20 of Set 7 | nantucket
# Processing Record 21 of Set 7 | broome
# Processing Record 22 of Set 7 | ixtapa
# Processing Record 23 of Set 7 | ofunato
# Processing Record 24 of Set 7 | yar-sale
# Processing Record 25 of Set 7 | labrea
# Processing Record 26 of Set 7 | upata
# Processing Record 27 of Set 7 | kamaishi
# Processing Record 28 of Set 7 | tuensang
# Processing Record 29 of Set 7 | husavik
# Processing Record 30 of Set 7 | pozo colorado
# Processing Record 31 of Set 7 | roma
# Processing Record 32 of Set 7 | trinidad
# Processing Record 33 of Set 7 | tabuk
# Processing Record 34 of Set 7 | bay roberts
# Processing Record 35 of Set 7 | marzuq
# Processing Record 36 of Set 7 | barwani
# Processing Record 37 of Set 7 | seymchan
# Processing Record 38 of Set 7 | guerrero negro
# Processing Record 39 of Set 7 | arlit
# Processing Record 40 of Set 7 | lebedyn
# Processing Record 41 of Set 7 | celestun
# Processing Record 42 of Set 7 | rio grande
# Processing Record 43 of Set 7 | palabuhanratu
# City not found.  Skipping...
# Processing Record 44 of Set 7 | yevlax
# Processing Record 45 of Set 7 | obo
# Processing Record 46 of Set 7 | auki
# Processing Record 47 of Set 7 | yenagoa
# Processing Record 48 of Set 7 | camana
# Processing Record 49 of Set 7 | omboue
# Processing Record 50 of Set 7 | fort nelson
# Processing Record 1 of Set 8 | skjervoy
# Processing Record 2 of Set 8 | brandfort
# Processing Record 3 of Set 8 | curup
# Processing Record 4 of Set 8 | peniche
# Processing Record 5 of Set 8 | nouadhibou
# Processing Record 6 of Set 8 | bolshiye uki
# City not found.  Skipping...
# Processing Record 7 of Set 8 | fort erie
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | arieseni
# Processing Record 10 of Set 8 | rampura
# Processing Record 11 of Set 8 | taltal
# Processing Record 12 of Set 8 | neiafu
# Processing Record 13 of Set 8 | coari
# Processing Record 14 of Set 8 | shuangcheng
# Processing Record 15 of Set 8 | kaitangata
# Processing Record 16 of Set 8 | faya
# Processing Record 17 of Set 8 | tromso
# Processing Record 18 of Set 8 | mantua
# Processing Record 19 of Set 8 | whitehorse
# Processing Record 20 of Set 8 | rantauprapat
# Processing Record 21 of Set 8 | aksarka
# Processing Record 22 of Set 8 | kamenskoye
# City not found.  Skipping...
# Processing Record 23 of Set 8 | narsaq
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | grand river south east
# City not found.  Skipping...
# Processing Record 26 of Set 8 | inongo
# Processing Record 27 of Set 8 | saint-augustin
# Processing Record 28 of Set 8 | falealupo
# City not found.  Skipping...
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | cooma
# Processing Record 31 of Set 8 | dubna
# Processing Record 32 of Set 8 | buala
# Processing Record 33 of Set 8 | rungata
# City not found.  Skipping...
# Processing Record 34 of Set 8 | coihaique
# Processing Record 35 of Set 8 | anloga
# Processing Record 36 of Set 8 | katangli
# Processing Record 37 of Set 8 | kincardine
# Processing Record 38 of Set 8 | sitrah
# Processing Record 39 of Set 8 | srednekolymsk
# Processing Record 40 of Set 8 | minot
# Processing Record 41 of Set 8 | cabedelo
# Processing Record 42 of Set 8 | ust-nera
# Processing Record 43 of Set 8 | kapoeta
# Processing Record 44 of Set 8 | eruwa
# Processing Record 45 of Set 8 | dryden
# Processing Record 46 of Set 8 | udachnyy
# Processing Record 47 of Set 8 | spornoye
# Processing Record 48 of Set 8 | ustye
# Processing Record 49 of Set 8 | sungairaya
# Processing Record 50 of Set 8 | saint-jean-port-joli
# Processing Record 1 of Set 9 | tarko-sale
# Processing Record 2 of Set 9 | clermont
# Processing Record 3 of Set 9 | atherton
# Processing Record 4 of Set 9 | boone
# Processing Record 5 of Set 9 | arman
# Processing Record 6 of Set 9 | qena
# Processing Record 7 of Set 9 | henties bay
# Processing Record 8 of Set 9 | channel-port aux basques
# Processing Record 9 of Set 9 | ostrovnoy
# Processing Record 10 of Set 9 | elko
# Processing Record 11 of Set 9 | barabai
# Processing Record 12 of Set 9 | ipixuna
# Processing Record 13 of Set 9 | batagay
# Processing Record 14 of Set 9 | saint john
# Processing Record 15 of Set 9 | kedrovyy
# Processing Record 16 of Set 9 | thaton
# Processing Record 17 of Set 9 | sidi ali
# Processing Record 18 of Set 9 | bonthe
# Processing Record 19 of Set 9 | alexandria
# Processing Record 20 of Set 9 | oyem
# Processing Record 21 of Set 9 | port shepstone
# Processing Record 22 of Set 9 | wattegama
# Processing Record 23 of Set 9 | thinadhoo
# Processing Record 24 of Set 9 | develi
# Processing Record 25 of Set 9 | palampur
# Processing Record 26 of Set 9 | opuwo
# Processing Record 27 of Set 9 | ruteng
# Processing Record 28 of Set 9 | chuy
# Processing Record 29 of Set 9 | qaqortoq
# Processing Record 30 of Set 9 | patacamaya
# Processing Record 31 of Set 9 | marmaris
# Processing Record 32 of Set 9 | le vauclin
# Processing Record 33 of Set 9 | hambantota
# Processing Record 34 of Set 9 | owase
# Processing Record 35 of Set 9 | fjerritslev
# Processing Record 36 of Set 9 | carora
# Processing Record 37 of Set 9 | vinhedo
# Processing Record 38 of Set 9 | chapais
# Processing Record 39 of Set 9 | iraucuba
# Processing Record 40 of Set 9 | dunedin
# Processing Record 41 of Set 9 | san jose
# Processing Record 42 of Set 9 | sorong
# Processing Record 43 of Set 9 | tawang
# Processing Record 44 of Set 9 | sawtell
# Processing Record 45 of Set 9 | saint-georges
# Processing Record 46 of Set 9 | pandan
# Processing Record 47 of Set 9 | eaton socon
# Processing Record 48 of Set 9 | cururupu
# Processing Record 49 of Set 9 | sao joao da barra
# Processing Record 50 of Set 9 | nieuw amsterdam
# Processing Record 1 of Set 10 | serrinha
# Processing Record 2 of Set 10 | maniitsoq
# Processing Record 3 of Set 10 | alquizar
# Processing Record 4 of Set 10 | glenluce
# Processing Record 5 of Set 10 | pauini
# Processing Record 6 of Set 10 | hunza
# City not found.  Skipping...
# Processing Record 7 of Set 10 | yulara
# Processing Record 8 of Set 10 | antalaha
# Processing Record 9 of Set 10 | eyl
# Processing Record 10 of Set 10 | kulhudhuffushi
# Processing Record 11 of Set 10 | olinda
# Processing Record 12 of Set 10 | katsuura
# Processing Record 13 of Set 10 | karratha
# Processing Record 14 of Set 10 | toliary
# City not found.  Skipping...
# Processing Record 15 of Set 10 | akyab
# Processing Record 16 of Set 10 | concordia
# Processing Record 17 of Set 10 | aykhal
# Processing Record 18 of Set 10 | goba
# Processing Record 19 of Set 10 | vestmannaeyjar
# Processing Record 20 of Set 10 | atagay
# Processing Record 21 of Set 10 | valparaiso
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | wulanhaote
# City not found.  Skipping...
# Processing Record 24 of Set 10 | sabzevar
# Processing Record 25 of Set 10 | lao cai
# Processing Record 26 of Set 10 | kavieng
# Processing Record 27 of Set 10 | barra do garcas
# Processing Record 28 of Set 10 | banda aceh
# Processing Record 29 of Set 10 | bahar
# Processing Record 30 of Set 10 | caceres
# Processing Record 31 of Set 10 | missoula
# Processing Record 32 of Set 10 | lata
# Processing Record 33 of Set 10 | gizo
# Processing Record 34 of Set 10 | talgar
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | inyonga
# Processing Record 37 of Set 10 | viseu
# Processing Record 38 of Set 10 | shunyi
# Processing Record 39 of Set 10 | fallon
# Processing Record 40 of Set 10 | mazyr
# Processing Record 41 of Set 10 | riviere-au-renard
# Processing Record 42 of Set 10 | ilinge
# Processing Record 43 of Set 10 | mallaig
# Processing Record 44 of Set 10 | sistranda
# Processing Record 45 of Set 10 | sisimiut
# Processing Record 46 of Set 10 | gazanjyk
# Processing Record 47 of Set 10 | wlodawa
# Processing Record 48 of Set 10 | agadez
# Processing Record 49 of Set 10 | bubaque
# Processing Record 50 of Set 10 | verkhoyansk
# Processing Record 1 of Set 11 | komsomolskiy
# Processing Record 2 of Set 11 | jabinyanah
# Processing Record 3 of Set 11 | ayolas
# Processing Record 4 of Set 11 | puerto gaitan
# Processing Record 5 of Set 11 | maloshuyka
# City not found.  Skipping...
# Processing Record 6 of Set 11 | samarai
# Processing Record 7 of Set 11 | ingham
# Processing Record 8 of Set 11 | changzhou
# Processing Record 9 of Set 11 | mys shmidta
# City not found.  Skipping...
# Processing Record 10 of Set 11 | stoyba
# City not found.  Skipping...
# Processing Record 11 of Set 11 | macaboboni
# City not found.  Skipping...
# Processing Record 12 of Set 11 | nemuro
# Processing Record 13 of Set 11 | fonte boa
# Processing Record 14 of Set 11 | mutsamudu
# City not found.  Skipping...
# Processing Record 15 of Set 11 | moron
# Processing Record 16 of Set 11 | villacidro
# Processing Record 17 of Set 11 | kloulklubed
# Processing Record 18 of Set 11 | bayan
# Processing Record 19 of Set 11 | buraydah
# Processing Record 20 of Set 11 | sidi bu zayd
# City not found.  Skipping...
# Processing Record 21 of Set 11 | pisco
# Processing Record 22 of Set 11 | bridgewater
# Processing Record 23 of Set 11 | san matias
# Processing Record 24 of Set 11 | abu kamal
# Processing Record 25 of Set 11 | nizhniy kuranakh
# Processing Record 26 of Set 11 | ambodifototra
# City not found.  Skipping...
# Processing Record 27 of Set 11 | gravdal
# Processing Record 28 of Set 11 | mbandaka
# Processing Record 29 of Set 11 | bilma
# Processing Record 30 of Set 11 | andros town
# Processing Record 31 of Set 11 | tabiauea
# City not found.  Skipping...
# Processing Record 32 of Set 11 | rawson
# Processing Record 33 of Set 11 | cap malheureux
# Processing Record 34 of Set 11 | naze
# Processing Record 35 of Set 11 | dwarka
# Processing Record 36 of Set 11 | mbigou
# Processing Record 37 of Set 11 | tianpeng
# Processing Record 38 of Set 11 | tynda
# Processing Record 39 of Set 11 | tessalit
# Processing Record 40 of Set 11 | miyako
# Processing Record 41 of Set 11 | arroyo
# Processing Record 42 of Set 11 | ulladulla
# Processing Record 43 of Set 11 | tura
# Processing Record 44 of Set 11 | lazaro cardenas
# Processing Record 45 of Set 11 | jurm
# Processing Record 46 of Set 11 | yeniseysk
# Processing Record 47 of Set 11 | maningrida
# Processing Record 48 of Set 11 | glendive
# Processing Record 49 of Set 11 | aktash
# Processing Record 50 of Set 11 | canmore
# Processing Record 1 of Set 12 | boromo
# Processing Record 2 of Set 12 | iracoubo
# Processing Record 3 of Set 12 | suihua
# Processing Record 4 of Set 12 | bousse
# Processing Record 5 of Set 12 | cabra
# Processing Record 6 of Set 12 | atka
# City not found.  Skipping...
# Processing Record 7 of Set 12 | krasnaya poyma
# Processing Record 8 of Set 12 | port keats
# Processing Record 9 of Set 12 | vernon
# Processing Record 10 of Set 12 | lakes entrance
# Processing Record 11 of Set 12 | college
# Processing Record 12 of Set 12 | asfi
# Processing Record 13 of Set 12 | albion
# Processing Record 14 of Set 12 | zarubino
# Processing Record 15 of Set 12 | kawalu
# Processing Record 16 of Set 12 | krasnoselkup
# Processing Record 17 of Set 12 | sivaki
# Processing Record 18 of Set 12 | tshikapa
# Processing Record 19 of Set 12 | marsh harbour
# Processing Record 20 of Set 12 | ulaanbaatar
# Processing Record 21 of Set 12 | asilah
# Processing Record 22 of Set 12 | hovd
# Processing Record 23 of Set 12 | coahuayana
# Processing Record 24 of Set 12 | teresina
# Processing Record 25 of Set 12 | vredendal
# Processing Record 26 of Set 12 | urumqi
# Processing Record 27 of Set 12 | durazno
# Processing Record 28 of Set 12 | suba
# Processing Record 29 of Set 12 | guozhen
# Processing Record 30 of Set 12 | kutum
# Processing Record 31 of Set 12 | labuhan
# Processing Record 32 of Set 12 | eldorado
# Processing Record 33 of Set 12 | isangel
# Processing Record 34 of Set 12 | katobu
# Processing Record 35 of Set 12 | ust-tsilma
# Processing Record 36 of Set 12 | jibuti
# Processing Record 37 of Set 12 | mahibadhoo
# Processing Record 38 of Set 12 | maceio
# Processing Record 39 of Set 12 | sandnessjoen
# Processing Record 40 of Set 12 | san fernando
# Processing Record 41 of Set 12 | mayo
# Processing Record 42 of Set 12 | sabaudia
# Processing Record 43 of Set 12 | ape
# Processing Record 44 of Set 12 | phuket
# Processing Record 45 of Set 12 | baykit
# Processing Record 46 of Set 12 | inderborskiy
# City not found.  Skipping...
# Processing Record 47 of Set 12 | toftir
# City not found.  Skipping...
# Processing Record 48 of Set 12 | caravelas
# Processing Record 49 of Set 12 | sampit
# Processing Record 50 of Set 12 | jamame
# Processing Record 1 of Set 13 | banjar
# Processing Record 2 of Set 13 | la macarena
# Processing Record 3 of Set 13 | kirkenes
# Processing Record 4 of Set 13 | sonkovo
# Processing Record 5 of Set 13 | dekar
# Processing Record 6 of Set 13 | luganville
# Processing Record 7 of Set 13 | praia
# Processing Record 8 of Set 13 | brainerd
# Processing Record 9 of Set 13 | macusani
# Processing Record 10 of Set 13 | venice
# Processing Record 11 of Set 13 | olesno
# Processing Record 12 of Set 13 | nong chik
# Processing Record 13 of Set 13 | havoysund
# Processing Record 14 of Set 13 | rocha
# Processing Record 15 of Set 13 | pietermaritzburg
# Processing Record 16 of Set 13 | eureka
# Processing Record 17 of Set 13 | houston
# Processing Record 18 of Set 13 | benghazi
# Processing Record 19 of Set 13 | kungurtug
# Processing Record 20 of Set 13 | bosaso
# Processing Record 21 of Set 13 | skalistyy
# City not found.  Skipping...
# Processing Record 22 of Set 13 | ocho rios
# Processing Record 23 of Set 13 | poum
# Processing Record 24 of Set 13 | mana
# Processing Record 25 of Set 13 | izvestkovyy
# Processing Record 26 of Set 13 | meyungs
# City not found.  Skipping...
# Processing Record 27 of Set 13 | berlevag
# Processing Record 28 of Set 13 | kathmandu
# Processing Record 29 of Set 13 | dese
# Processing Record 30 of Set 13 | comodoro rivadavia
# Processing Record 31 of Set 13 | santa isabel do rio negro
# Processing Record 32 of Set 13 | nyurba
# Processing Record 33 of Set 13 | mahajanga
# Processing Record 34 of Set 13 | palmerston
# Processing Record 35 of Set 13 | along
# Processing Record 36 of Set 13 | pangnirtung
# Processing Record 37 of Set 13 | verkhnyaya inta
# Processing Record 38 of Set 13 | muroto
# Processing Record 39 of Set 13 | tofield
# Processing Record 40 of Set 13 | oudtshoorn
# Processing Record 41 of Set 13 | byron bay
# Processing Record 42 of Set 13 | whitianga
# Processing Record 43 of Set 13 | jutai
# Processing Record 44 of Set 13 | fasa
# Processing Record 45 of Set 13 | san andres
# Processing Record 46 of Set 13 | saint-leu
# Processing Record 47 of Set 13 | talawdi
# City not found.  Skipping...
# Processing Record 48 of Set 13 | shaartuz
# City not found.  Skipping...
# Processing Record 49 of Set 13 | walla walla
# Processing Record 50 of Set 13 | haibowan
# City not found.  Skipping...
# Processing Record 1 of Set 14 | erzin
# Processing Record 2 of Set 14 | mogadishu
# Processing Record 3 of Set 14 | grand forks
# Processing Record 4 of Set 14 | algiers
# Processing Record 5 of Set 14 | karaton
# Processing Record 6 of Set 14 | sulurpeta
# City not found.  Skipping...
# Processing Record 7 of Set 14 | mitsamiouli
# Processing Record 8 of Set 14 | yumen
# Processing Record 9 of Set 14 | marsa matruh
# Processing Record 10 of Set 14 | nkoteng
# Processing Record 11 of Set 14 | lilongwe
# Processing Record 12 of Set 14 | vao
# Processing Record 13 of Set 14 | korla
# Processing Record 14 of Set 14 | ullapool
# Processing Record 15 of Set 14 | seoul
# Processing Record 16 of Set 14 | port-cartier
# Processing Record 17 of Set 14 | pontianak
# Processing Record 18 of Set 14 | victor harbor
# Processing Record 19 of Set 14 | mezen
# Processing Record 20 of Set 14 | jati
# Processing Record 21 of Set 14 | novobirilyussy
# Processing Record 22 of Set 14 | gigmoto
# Processing Record 23 of Set 14 | sambava
# Processing Record 24 of Set 14 | karakol
# Processing Record 25 of Set 14 | poronaysk
# Processing Record 26 of Set 14 | zhuanghe
# Processing Record 27 of Set 14 | jiroft
# City not found.  Skipping...
# Processing Record 28 of Set 14 | mutare
# Processing Record 29 of Set 14 | nueve de julio
# Processing Record 30 of Set 14 | shingu
# Processing Record 31 of Set 14 | vostok
# Processing Record 32 of Set 14 | barra patuca
# Processing Record 33 of Set 14 | raudeberg
# Processing Record 34 of Set 14 | puerto madryn
# Processing Record 35 of Set 14 | fastiv
# Processing Record 36 of Set 14 | kirakira
# Processing Record 37 of Set 14 | taunggyi
# Processing Record 38 of Set 14 | izmit
# Processing Record 39 of Set 14 | nueva loja
# Processing Record 40 of Set 14 | carira
# Processing Record 41 of Set 14 | kyzyl-suu
# Processing Record 42 of Set 14 | sorland
# Processing Record 43 of Set 14 | kyra
# Processing Record 44 of Set 14 | gornopravdinsk
# Processing Record 45 of Set 14 | wiwili
# Processing Record 46 of Set 14 | bolungarvik
# City not found.  Skipping...
# Processing Record 47 of Set 14 | westport
# Processing Record 48 of Set 14 | necochea
# Processing Record 49 of Set 14 | den helder
# Processing Record 50 of Set 14 | laguna
# Processing Record 1 of Set 15 | puerto madero
# Processing Record 2 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 15 | singkang
# Processing Record 4 of Set 15 | shimoda
# Processing Record 5 of Set 15 | morro bay
# Processing Record 6 of Set 15 | tocopilla
# Processing Record 7 of Set 15 | luba
# Processing Record 8 of Set 15 | hinatuan
# Processing Record 9 of Set 15 | vyartsilya
# Processing Record 10 of Set 15 | shaunavon
# Processing Record 11 of Set 15 | the pas
# Processing Record 12 of Set 15 | khorol
# Processing Record 13 of Set 15 | coquimbo
# Processing Record 14 of Set 15 | khani
# Processing Record 15 of Set 15 | rjukan
# Processing Record 16 of Set 15 | marystown
# Processing Record 17 of Set 15 | gushikawa
# Processing Record 18 of Set 15 | fez
# Processing Record 19 of Set 15 | springfield
# Processing Record 20 of Set 15 | redlands
# Processing Record 21 of Set 15 | khorinsk
# Processing Record 22 of Set 15 | alekseyevsk
# Processing Record 23 of Set 15 | smithers
# Processing Record 24 of Set 15 | denau
# City not found.  Skipping...
# Processing Record 25 of Set 15 | banos
# Processing Record 26 of Set 15 | ambilobe
# Processing Record 27 of Set 15 | hun
# Processing Record 28 of Set 15 | mirina
# City not found.  Skipping...
# Processing Record 29 of Set 15 | bilibino
# Processing Record 30 of Set 15 | quelimane
# Processing Record 31 of Set 15 | nangomba
# Processing Record 32 of Set 15 | karauzyak
# City not found.  Skipping...
# Processing Record 33 of Set 15 | lasa
# Processing Record 34 of Set 15 | birao
# Processing Record 35 of Set 15 | papetoai
# Processing Record 36 of Set 15 | mareeba
# Processing Record 37 of Set 15 | shizukuishi
# Processing Record 38 of Set 15 | paita
# Processing Record 39 of Set 15 | wahpeton
# Processing Record 40 of Set 15 | virginia beach
# Processing Record 41 of Set 15 | druzhba
# Processing Record 42 of Set 15 | kristianstad
# Processing Record 43 of Set 15 | noumea
# Processing Record 44 of Set 15 | kondinskoye
# Processing Record 45 of Set 15 | jinchang
# Processing Record 46 of Set 15 | broadstairs
# Processing Record 47 of Set 15 | calabasas
# Processing Record 48 of Set 15 | tete
# Processing Record 49 of Set 15 | general roca
# Processing Record 50 of Set 15 | bowen
# Processing Record 1 of Set 16 | arriana
# Processing Record 2 of Set 16 | ornskoldsvik
# Processing Record 3 of Set 16 | port blair
# Processing Record 4 of Set 16 | halvad
# Processing Record 5 of Set 16 | susehri
# Processing Record 6 of Set 16 | campos novos
# Processing Record 7 of Set 16 | tumannyy
# City not found.  Skipping...
# Processing Record 8 of Set 16 | ciudad bolivar
# Processing Record 9 of Set 16 | malanje
# Processing Record 10 of Set 16 | lala
# Processing Record 11 of Set 16 | dukat
# ------------------------------
# Date retrieval complete
# ------------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 702

# %%
# Convert the array of dictionaries to a DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0              Valdivia -39.8142  -73.2459     75.20        41           0
# 1            Bredasdorp -34.5322   20.0403     69.80        78         100
# 2                Castro -24.7911  -50.0119     74.14        86          51
# 3         Leningradskiy  69.3833  178.4167    -13.58        88         100
# 4                Khasan  42.4308  130.6434     16.36        83           0
# 5  Vila Franca Do Campo  37.7167  -25.4333     62.01        94          75
# 6              Hermanus -34.4187   19.2345     71.01        81          28
# 7          Quatre Cocos -20.2078   57.7625     78.01        94          75
# 8               Rikitea -23.1203 -134.9692     77.59        78          33
# 9                Kodiak  57.7900 -152.4072     32.00        93          20
#
#    Wind Speed Country                 Date
# 0        6.91      CL  2021-01-13 20:12:02
# 1       16.11      ZA  2021-01-13 20:15:57
# 2        9.84      BR  2021-01-13 20:15:57
# 3        8.16      RU  2021-01-13 20:15:57
# 4       14.99      RU  2021-01-13 20:15:57
# 5        9.22      PT  2021-01-13 20:15:57
# 6        8.99      ZA  2021-01-13 20:13:29
# 7        2.30      MU  2021-01-13 20:15:57
# 8       15.79      PF  2021-01-13 20:15:57
# 9       10.49      US  2021-01-13 20:15:57

# %%
# Create the CSV output file
output_data_file = "weather_database/WeatherPY_Database.csv"

# Export city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
