# %%
# Import dependencies
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Create a set of 2,000 random geo coordinates
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the geo coordinates to a list
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on geocoordinates
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combination
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# puerto ayora ec
# butaritari ki
# beringovskiy ru
# olafsvik is
# ushuaia ar
# hilo us
# mataura pf
# rikitea pf
# mataura pf
# vaini to
# upernavik gl
# mataura pf
# roald no
# cabra ph
# puerto ayora ec
# rasinari ro
# aklavik ca
# khonuu ru
# khatanga ru
# samusu ws
# villarrica co
# rikitea pf
# punta arenas cl
# laguna br
# kalvarija lt
# puerto ayora ec
# butaritari ki
# port alfred za
# hobart au
# daru pg
# oktyabrskoye ru
# busselton au
# punta arenas cl
# tecoanapa mx
# albany au
# harper lr
# albany au
# faanui pf
# port-cartier ca
# mataura pf
# taolanaro mg
# hobart au
# hobart au
# matara lk
# opuwo na
# lavrentiya ru
# mahebourg mu
# upernavik gl
# namibe ao
# east london za
# filadelfia py
# amderma ru
# manavalakurichi in
# luderitz na
# port elizabeth za
# puerto ayora ec
# sakakah sa
# reefton nz
# lata sb
# busselton au
# shubarkuduk kz
# atuona pf
# dinard fr
# puerto ayora ec
# mataura pf
# sorland no
# lebu cl
# mogadishu so
# pedernales do
# ...

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each geocoordinate
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737
